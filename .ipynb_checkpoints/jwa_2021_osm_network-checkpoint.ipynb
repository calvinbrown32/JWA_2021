# %% [markdown]
# """This Script uses the sample-project environment, with the osmnx module updated.
# To update the osmnx module within the sample-project environment, I ran the following
# conda commands in the terminal:
#
# 1)Duplicate the sample-project environment:
# conda create --name sample-project_2  --clone sample-project
#
# 2)Update osmnx:
# conda update osmnx
#
# This script creates a place boundary and downloads the pois within that polygon. Next, it downloads network data:
# osm edges and nodes and exports this to a geopackage.
# """

# %%
import os
import geopandas as gpd
import osmnx as ox
import matplotlib.pyplot as plt
import networkx as nx
import fiona
from descartes import PolygonPatch
from shapely.geometry import Point, LineString, Polygon
ox.config(log_console=True, use_cache=True)
ox.__version__
# Out:
# '1.1.2'
# 2021-12-21 20:26:45 Configured OSMnx 1.1.2
# 2021-12-21 20:26:45 HTTP response caching is on

# %%
from IPython.display import display

# %%
#For graphing features in jupyter notebook:
# %matplotlib inline
# ox.config(log_console=True, use_cache=True)
# ox.__version__

# %%
PROJECT_FOLDER = r"/Users/calvindechicago/Documents/GitHub/JWA_2021"
COUNTY_POLYGON = os.path.join(PROJECT_FOLDER, "Data", "osm_county_polygon.gpkg" )

STUDY_AREA = "/Users/calvindechicago/Documents/GitHub/JWA_2021/code_outputs/route2_and_max_yellow/route2_max_yellow_buffer_poly.gpkg"
ROUTE_2_STOPS = '/Users/calvindechicago/Documents/GitHub/JWA_2021/data/Data_from_JWA/Route2_Stops.shp'
ROUTE_2_STOPS_TEST = '/Users/calvindechicago/Documents/GitHub/JWA_2021/data/route_2_stops_test/route_2_stops_test.gpkg'
MAX_YELLOW_STOPS = '/Users/calvindechicago/Documents/GitHub/JWA_2021/data/Data_from_JWA/MAX_Yellow_stops.shp'
#pois_export = os.path.join(PROJECT_FOLDER, "Data", "From_Public_Sources", "OSM_Data", "singapore_poi.shp")
pois_gpkg = os.path.join(PROJECT_FOLDER, "Data", "From_Public_Sources", "OSM", "poi.gpkg")
network_output = os.path.join(PROJECT_FOLDER, "Data", "network.gpkg")

# %%
# get the boundary polygon for the city or county. This polygon will be used to pull network and POIs
county_poly = ox.geocoder.geocode_to_gdf('Multnomah County')
county_proj = ox.project_gdf(county_poly,4326)
# Out:
# 2021-12-21 20:26:45 Retrieved response from cache file "cache/8cf5ce47f3c71ddf2f130625dfbd35014712c804.json"
# 2021-12-21 20:26:46 Created GeoDataFrame with 1 rows from 1 queries
# 2021-12-21 20:26:46 Projected GeoDataFrame to 4326

# %%
# Plot County geometry
county_proj.plot()
# Out:
# <AxesSubplot:>

# %%
# Export County Geometry

county_proj.to_file(COUNTY_POLYGON, layer='county_poly', driver="GPKG")

# %%
# Use this polygon to pull network in osmnx

polygon = county_proj['geometry'].iloc[0]

# %%
# PULL NETWORK
G = ox.graph_from_polygon(polygon)
print('Making the graph undirected')
G = G.to_undirected()
# Out:
# 2021-12-21 20:27:03 Projected GeoDataFrame to +proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-12-21 20:27:03 Projected GeoDataFrame to epsg:4326
# 2021-12-21 20:27:03 Projected GeoDataFrame to +proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-12-21 20:27:03 Projected GeoDataFrame to epsg:4326
# 2021-12-21 20:27:03 Requesting data within polygon from API in 1 request(s)
# 2021-12-21 20:27:05 Retrieved response from cache file "cache/3cfeec9a2cb225e9357ef95697aa2431ba87fac8.json"
# 2021-12-21 20:27:05 Got all network data within polygon from API in 1 request(s)
# 2021-12-21 20:27:05 Creating graph from downloaded OSM data...
# 2021-12-21 20:27:19 Created graph with 469799 nodes and 966273 edges
# 2021-12-21 20:27:28 Added length attributes to graph edges
# 2021-12-21 20:27:28 Identifying all nodes that lie outside the polygon...
# 2021-12-21 20:27:54 Created nodes GeoDataFrame from graph
# 2021-12-21 20:28:19 Created r-tree spatial index for 469799 geometries
# 2021-12-21 20:28:25 Identified 459136 geometries inside polygon
# 2021-12-21 20:28:38 Removed 10663 nodes outside polygon
# 2021-12-21 20:28:38 Truncated graph by polygon
# 2021-12-21 20:28:40 Begin topologically simplifying the graph...
# 2021-12-21 20:28:56 Identified 102685 edge endpoints
# 2021-12-21 20:29:44 Simplified graph: 459136 to 102685 nodes, 944700 to 270186 edges
# 2021-12-21 20:29:45 Identifying all nodes that lie outside the polygon...
# 2021-12-21 20:29:50 Created nodes GeoDataFrame from graph
# 2021-12-21 20:29:54 Created r-tree spatial index for 102685 geometries
# 2021-12-21 20:29:55 Identified 95957 geometries inside polygon
# 2021-12-21 20:29:58 Removed 6728 nodes outside polygon
# 2021-12-21 20:30:01 Removed 34 isolated nodes
# 2021-12-21 20:30:07 Got largest weakly connected component (95426 of 95923 total nodes)
# 2021-12-21 20:30:07 Truncated graph by polygon
# 2021-12-21 20:30:09 Counted undirected street segments incident on each node
# 2021-12-21 20:30:09 graph_from_polygon returned graph with 95426 nodes and 253376 edges
# Making the graph undirected

# %%
# Save Network to File

ox.io.save_graph_geopackage(G,filepath= network_output)

# %% [markdown]
# # BELOW IS FROM OSMNX ISOCHRONE GUIDE
# ### https://github.com/gboeing/osmnx-examples/blob/main/notebooks/13-isolines-isochrones.ipynb
# ### UHELSKINKI AUTOGIS and Network Analysis:
# ### https://autogis-site.readthedocs.io/en/latest/notebooks/L6/01_network_analysis.html
# ## See Also:
# ### https://pythoncharmers.com/blog/travel-distance-python-with-geopandas-folium-alphashape-osmnx-buffer.html
# ### http://kuanbutts.com/2017/12/16/osmnx-isochrones/

# %%
# configure the place, network type, trip times, and travel speed
place = {"city": "Portland", "state": "Oregon"}
network_type = "walk"
trip_times = [5, 10, 15, 20, 25]  # in minutes
travel_speed = 4.5  # walking speed in km/hour (about 2.8 mph)

# %%
# download the street network
G = ox.graph_from_place(place, network_type=network_type)

# %%
# find the centermost node and then project the graph to UTM
gdf_nodes = ox.graph_to_gdfs(G, edges=False)
x, y = gdf_nodes['geometry'].unary_union.centroid.xy
center_node = ox.get_nearest_node(G, (y[0], x[0]))
# Out:
# 2021-12-21 20:58:55 Created nodes GeoDataFrame from graph
# /Users/calvindechicago/anaconda3/envs/2021_all/lib/python3.10/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-12-21 20:58:56 Created nodes GeoDataFrame from graph

# %%
# Read in Route 2 Stops to geodataframe

#route_2_stops = gpd.read_file(ROUTE_2_STOPS) 
route_2_stops = gpd.read_file(ROUTE_2_STOPS_TEST, layer='route_2_stops_test')

# %%
route_2_stops
# Out:
#     map_id          map_name stop_id            stop_name  \
# 0  c14266b  Untitled Project    1391  SE Division & 138th
# 1  c14266b  Untitled Project    1392  SE Division & 139th
# 2  c14266b  Untitled Project    1390  SE Division & 135th
# 3  c14266b  Untitled Project    1389  SE Division & 136th
# 4  c14266b  Untitled Project    1375   SE Division & 12th
# 5  c14266b  Untitled Project    1376   SE Division & 12th
# 6  c14266b  Untitled Project    1420   SE Division & 17th
# 7  c14266b  Untitled Project    1419   SE Division & 17th
# 8  c14266b  Untitled Project    1496    SE Division & 8th
#
#                    lines                        geometry
# 0  2 Division (Outbound)  POINT (7683880.992 676322.660)
# 1   2 Division (Inbound)  POINT (7683942.982 676401.711)
# 2   2 Division (Inbound)  POINT (7683091.511 676411.365)
# 3  2 Division (Outbound)  POINT (7683448.636 676324.366)
# 4  2 Division (Outbound)  POINT (7649950.527 677498.715)
# 5   2 Division (Inbound)  POINT (7649874.414 677539.406)
# 6   2 Division (Inbound)  POINT (7651329.024 677487.897)
# 7  2 Division (Outbound)  POINT (7651255.109 677457.037)
# 8   2 Division (Inbound)  POINT (7648875.775 678002.288)

# %%
#PROJECT THE GRAPH
G = ox.project_graph(G)

# %%
# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60 #km per hour to m per minute
for u, v, k, data in G.edges(data=True, keys=True):
    data['time'] = data['length'] / meters_per_minute

# %%
# get one color for each isochrone
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap='plasma', start=0, return_hex=True)

# %%
# color the nodes according to isochrone then plot the street network
node_colors = {}
for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
    subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance='time')
    for node in subgraph.nodes():
        node_colors[node] = color
nc = [node_colors[node] if node in node_colors else 'none' for node in G.nodes()]
ns = [15 if node in node_colors else 0 for node in G.nodes()]
fig, ax = ox.plot_graph(G, node_color=nc, node_size=ns, node_alpha=0.8, node_zorder=2,
                        bgcolor='k', edge_linewidth=0.2, edge_color='#999999')
# Out:
# 2021-12-21 21:11:53 Begin plotting the graph...
# 2021-12-21 21:12:04 Created edges GeoDataFrame from graph
# 2021-12-21 21:12:17 Created nodes GeoDataFrame from graph
# 2021-12-21 21:12:26 Finished plotting the graph

# %%
# make the isochrone polygons
isochrone_polys = []
for trip_time in sorted(trip_times, reverse=True):
    subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance='time')
    node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
    bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
    isochrone_polys.append(bounding_poly)

# %%
# plot the network then add isochrones as colored descartes polygon patches
fig, ax = ox.plot_graph(G, show=False, close=False, edge_color='#999999', edge_alpha=0.2,
                        node_size=0, bgcolor='k')
for polygon, fc in zip(isochrone_polys, iso_colors):
    patch = PolygonPatch(polygon, fc=fc, ec='none', alpha=0.6, zorder=-1)
    ax.add_patch(patch)
plt.show()
# Out:
# 2021-12-21 21:12:41 Begin plotting the graph...
# 2021-12-21 21:12:52 Created edges GeoDataFrame from graph
# 2021-12-21 21:13:12 Finished plotting the graph
# /Users/calvindechicago/anaconda3/envs/2021_all/lib/python3.10/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
def make_iso_polys(G, center_node, edge_buff=25, node_buff=50):
    isochrone_polys = []
    for trip_time in sorted(trip_times, reverse=True):
        subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance='time')

        node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
        nodes_gdf = gpd.GeoDataFrame({'id': subgraph.nodes()}, geometry=node_points)
        nodes_gdf = nodes_gdf.set_index('id')

        edge_lines = []
        for n_fr, n_to in subgraph.edges():
            f = nodes_gdf.loc[n_fr].geometry
            t = nodes_gdf.loc[n_to].geometry
            edge_lookup = G.get_edge_data(n_fr, n_to)[0].get('geometry',  LineString([f,t]))
            edge_lines.append(edge_lookup)

        n = nodes_gdf.buffer(node_buff).geometry
        e = gpd.GeoSeries(edge_lines).buffer(edge_buff).geometry
        all_gs = list(n) + list(e)
        new_iso = gpd.GeoSeries(all_gs).unary_union

    return isochrone_polys

# %%
# Project route_2_stops to UTM CRS of graph
route_2_stops = route_2_stops.to_crs(epsg=32610)

# %%
route_2_stops['geometry'].y
# Out:
# 0    676322.659550
# 1    676401.711327
# 2    676411.364512
# 3    676324.366319
# 4    677498.714578
# 5    677539.406319
# 6    677487.897083
# 7    677457.037211
# 8    678002.288490
# dtype: float64

# %%
route_2_stops.crs
# Out:
# <Derived Projected CRS: EPSG:32610>
# Name: WGS 84 / UTM zone 10N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 126°W and 120°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - British Columbia (BC); Northwest Territories (NWT); Nunavut; Yukon. United States (USA) - Alaska (AK).
# - bounds: (-126.0, 0.0, -120.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 10N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
coord_list = [(x,y) for x,y in zip(route_2_stops['geometry'].x , route_2_stops['geometry'].y)]

# %%
coord_list
# Out:
# [(7683880.9916699985, 676322.6595497348),
#  (7683942.982302938, 676401.7113266895),
#  (7683091.510996986, 676411.3645118091),
#  (7683448.636492476, 676324.3663189504),
#  (7649950.526746695, 677498.7145782982),
#  (7649874.414281508, 677539.4063193006),
#  (7651329.023608307, 677487.8970828258),
#  (7651255.108666411, 677457.037211403),
#  (7648875.774575208, 678002.2884895073)]

# %%
#nearest_nodes = []
nearest_node = ox.distance.nearest_nodes(G, route_2_stops['geometry'].x, route_2_stops['geometry'].y )
#nearest_nodes.append(nearest_node)
# Out:
# 2021-12-21 22:09:57 Created nodes GeoDataFrame from graph

# %%
nearest_nodes
# Out:
# [[40630800,
#   40561773,
#   6149345392,
#   4118393883,
#   6149345392,
#   6149345392,
#   7008409115,
#   40426914,
#   1617371956]]

# %%
study_area = gpd.read_file(STUDY_AREA)

# %%
study_area.columns
# Out:
# Index(['full_name', 'dir_name', 'line_name', 'geometry'], dtype='object')

# %%
type(study_area)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
study_area.crs
# Out:
# <Derived Projected CRS: EPSG:2269>
# Name: NAD83 / Oregon North (ft)
# Axis Info [cartesian]:
# - X[east]: Easting (foot)
# - Y[north]: Northing (foot)
# Area of Use:
# - name: United States (USA) - Oregon - counties of Baker; Benton; Clackamas; Clatsop; Columbia; Gilliam; Grant; Hood River; Jefferson; Lincoln; Linn; Marion; Morrow; Multnomah; Polk; Sherman; Tillamook; Umatilla; Union; Wallowa; Wasco; Washington; Wheeler; Yamhill.
# - bounds: (-124.17, 43.95, -116.47, 46.26)
# Coordinate Operation:
# - name: SPCS83 Oregon North zone (International feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
study_area_proj = ox.project_gdf(study_area,4326)
# Out:
# 2021-12-20 20:16:21 Projected GeoDataFrame to 4326

# %%
# Use this polygon to pull network in osmnx

study_area_proj = study_area_proj['geometry'].iloc[0]

# %%
# PULL NETWORK
G = ox.graph_from_polygon(study_area_proj, network_type= "walk")
print('Making the graph undirected')
G = G.to_undirected()
# Out:
# 2021-12-20 22:47:47 Projected GeoDataFrame to +proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-12-20 22:47:47 Projected GeoDataFrame to epsg:4326
# 2021-12-20 22:47:47 Projected GeoDataFrame to +proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-12-20 22:47:47 Projected GeoDataFrame to epsg:4326
# 2021-12-20 22:47:47 Requesting data within polygon from API in 1 request(s)
# 2021-12-20 22:47:47 Retrieved response from cache file "cache/6057a6543e2314069b0a1a7d0ed240a20909cbc4.json"
# 2021-12-20 22:47:47 Got all network data within polygon from API in 1 request(s)
# 2021-12-20 22:47:47 Creating graph from downloaded OSM data...
# 2021-12-20 22:47:51 Created graph with 123575 nodes and 280474 edges
# 2021-12-20 22:47:52 Added length attributes to graph edges
# 2021-12-20 22:47:52 Identifying all nodes that lie outside the polygon...
# 2021-12-20 22:47:58 Created nodes GeoDataFrame from graph
# 2021-12-20 22:48:02 Created r-tree spatial index for 123575 geometries
# 2021-12-20 22:48:05 Identified 118845 geometries inside polygon
# 2021-12-20 22:48:08 Removed 4730 nodes outside polygon
# 2021-12-20 22:48:08 Truncated graph by polygon
# 2021-12-20 22:48:08 Begin topologically simplifying the graph...
# 2021-12-20 22:48:12 Identified 36211 edge endpoints
# 2021-12-20 22:48:24 Simplified graph: 118845 to 36211 nodes, 270600 to 105332 edges
# 2021-12-20 22:48:24 Identifying all nodes that lie outside the polygon...
# 2021-12-20 22:48:25 Created nodes GeoDataFrame from graph
# 2021-12-20 22:48:26 Created r-tree spatial index for 36211 geometries
# 2021-12-20 22:48:27 Identified 29311 geometries inside polygon
# 2021-12-20 22:48:28 Removed 6900 nodes outside polygon
# 2021-12-20 22:48:29 Removed 55 isolated nodes
# 2021-12-20 22:48:31 Got largest weakly connected component (28924 of 29256 total nodes)
# 2021-12-20 22:48:31 Truncated graph by polygon
# 2021-12-20 22:48:32 Counted undirected street segments incident on each node
# 2021-12-20 22:48:32 graph_from_polygon returned graph with 28924 nodes and 85294 edges
# Making the graph undirected

# %%
trip_times = [10.68] #in minutes
travel_speed = 4.5 #walking speed in km/hour

# %%
fig, ax = ox.plot_graph(G)
# Out:
# 2021-12-20 22:40:26 Begin plotting the graph...
# 2021-12-20 22:40:31 Created edges GeoDataFrame from graph
# 2021-12-20 22:40:37 Created nodes GeoDataFrame from graph
# 2021-12-20 22:40:41 Finished plotting the graph

# %%
# find the centermost node and then project the graph to UTM
gdf_nodes = ox.graph_to_gdfs(G, edges=False)
x, y = gdf_nodes['geometry'].unary_union.centroid.xy
center_node = ox.get_nearest_node(G, (y[0], x[0]))
G = ox.project_graph(G)
# Out:
# 2021-12-20 22:50:45 Created nodes GeoDataFrame from graph
# /Users/calvindechicago/anaconda3/envs/2021_all/lib/python3.10/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# 2021-12-20 22:50:46 Created nodes GeoDataFrame from graph
# 2021-12-20 22:50:48 Created nodes GeoDataFrame from graph
# 2021-12-20 22:50:51 Projected GeoDataFrame to +proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-12-20 22:50:55 Created edges GeoDataFrame from graph
# 2021-12-20 22:50:57 Projected GeoDataFrame to +proj=utm +zone=10 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2021-12-20 22:50:59 Created graph from node/edge GeoDataFrames
# 2021-12-20 22:50:59 Projected graph with 28924 nodes and 42796 edges

# %%
# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60 #km per hour to m per minute
for u, v, k, data in G.edges(data=True, keys=True):
    data['time'] = data['length'] / meters_per_minute

# %% [markdown]
# ## Plots nodes you can reach on foot within each time
#
# How far can you walk in 5, 10, 15, 20, and 25 minutes from the origin node? We'll use NetworkX to induce a subgraph of G within each distance, based on trip time and travel speed.

# %%
# get one color for each isochrone
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap='plasma', start=0, return_hex=True)

# %%
# color the nodes according to isochrone then plot the street network
node_colors = {}
for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
    subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance='time')
    for node in subgraph.nodes():
        node_colors[node] = color
nc = [node_colors[node] if node in node_colors else 'none' for node in G.nodes()]
ns = [15 if node in node_colors else 0 for node in G.nodes()]
fig, ax = ox.plot_graph(G, node_color=nc, node_size=ns, node_alpha=0.8, node_zorder=2,
                        bgcolor='k', edge_linewidth=0.2, edge_color='#999999')
# Out:
# 2021-12-20 22:54:12 Begin plotting the graph...
# 2021-12-20 22:54:14 Created edges GeoDataFrame from graph
# 2021-12-20 22:54:16 Created nodes GeoDataFrame from graph
# 2021-12-20 22:54:19 Finished plotting the graph

# %%
# make the isochrone polygons
isochrone_polys = []
for trip_time in sorted(trip_times, reverse=True):
    subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance='time')
    node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
    bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
    isochrone_polys.append(bounding_poly)

# %%
# Create geodataframe from 
isochrone_gdf = gpd.GeoDataFrame(isochrone_polys, geometry=0)

# %%
#SET CRS
isochrone_gdf = isochrone_gdf.set_crs(epsg=32610)

# %%
print(isochrone_gdf.crs)
# Out:
# epsg:32610

# %%
isochrone_export="/Users/calvindechicago/Documents/GitHub/JWA_2021/code_outputs/isochrones/iso_test.gpkg"

# %%
isochrone_gdf.to_file(isochrone_export, layer='iso_test', driver="GPKG")

# %%
# Retrieve only edges from the graph - To geodataframe 

edges = ox.graph_to_gdfs(G, nodes=False, edges=True)
# Out:
# 2021-12-20 22:51:01 Created edges GeoDataFrame from graph

# %%
edges.shape
# Out:
# (42796, 16)

# %%
subgraph = nx.ego_graph(G, center_node, radius=1000.00, distance='length')

# %%
len(subgraph)
# Out:
# 43

# %%
fig, ax = ox.plot_graph(subgraph)
# Out:
# 2021-12-20 22:51:09 Begin plotting the graph...
# 2021-12-20 22:51:09 Created edges GeoDataFrame from graph
# 2021-12-20 22:51:09 Created nodes GeoDataFrame from graph
# 2021-12-20 22:51:09 Finished plotting the graph

# %%
nc = ['white' if node in subgraph else 'none' for node in G.nodes()]
ns = [15 if node in subgraph else 0 for node in G.nodes()]
fig, ax = ox.plot_graph(
    G,
    node_color=nc,
    node_size=ns,
    node_alpha=0.8,
    edge_linewidth=0.2,
    edge_color='#999999'
)
# Out:
# 2021-12-20 22:28:15 Begin plotting the graph...
# 2021-12-20 22:28:17 Created edges GeoDataFrame from graph
# 2021-12-20 22:28:20 Created nodes GeoDataFrame from graph
# 2021-12-20 22:28:23 Finished plotting the graph

# %%
isochrone_polys = []
subgraph = nx.ego_graph(G, center_node, radius=10000000, distance='length')
node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
isochrone_polys.append(bounding_poly)

# %%
for item in isochrone_polys:
    print(item)
# Out:
# POLYGON ((526733.8759254111 5039973.325352954, 526674.3728365708 5040070.3284033695, 526675.0667732805 5040149.600735227, 526891.7708894899 5040308.020523252, 526912.7808803411 5040308.166184108, 526945.8969226436 5040070.2223532805, 526945.6737612193 5040034.891794176, 526846.0162236338 5039988.624913101, 526812.4524926714 5039977.593629234, 526733.8759254111 5039973.325352954))

# %%
def make_iso_polys(G, edge_buff=25, node_buff=50, infill=False):
    isochrone_polys = []
    for trip_time in sorted(trip_times, reverse=True):
        subgraph = nx.ego_graph(G, center_node, radius=trip_time, distance='time')

        node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
        nodes_gdf = gpd.GeoDataFrame({'id': subgraph.nodes()}, geometry=node_points)
        nodes_gdf = nodes_gdf.set_index('id')

        edge_lines = []
        for n_fr, n_to in subgraph.edges():
            f = nodes_gdf.loc[n_fr].geometry
            t = nodes_gdf.loc[n_to].geometry
            edge_lookup = G.get_edge_data(n_fr, n_to)[0].get('geometry',  LineString([f,t]))
            edge_lines.append(edge_lookup)

        n = nodes_gdf.buffer(node_buff).geometry
        e = gpd.GeoSeries(edge_lines).buffer(edge_buff).geometry
        all_gs = list(n) + list(e)
        new_iso = gpd.GeoSeries(all_gs).unary_union
        
        # try to fill in surrounded areas so shapes will appear solid and blocks without white space inside them
        if infill:
            new_iso = Polygon(new_iso.exterior)
        isochrone_polys.append(new_iso)
    return isochrone_polys

isochrone_polys = make_iso_polys(G, edge_buff=25, node_buff=0, infill=True)
fig, ax = ox.plot_graph(G, show=False, close=False, edge_color='#999999', edge_alpha=0.2,
                        node_size=0, bgcolor='k')
for polygon, fc in zip(isochrone_polys, iso_colors):
    patch = PolygonPatch(polygon, fc=fc, ec='none', alpha=0.6, zorder=-1)
    ax.add_patch(patch)
plt.show()
# Out:
# 2021-12-20 23:40:58 Begin plotting the graph...
# 2021-12-20 23:41:00 Created edges GeoDataFrame from graph
# 2021-12-20 23:41:04 Finished plotting the graph
# /Users/calvindechicago/anaconda3/envs/2021_all/lib/python3.10/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# TO DO: 
# 1 DONE join block group pop totals with block group geographies and export
# 2 Make 1/2 mile isochrones for each transit stop and export
# 3 Merge Isochrones
# 4 Create Voronoi Polygons within merged isochrones
# 5 Where Voronoi Polygons overlap multiple blockgroups, find proportion that they overlap and calculate proportional total population.
# 6 join Voronoi Stats with each Stop
# Create Leaflet Layer for Voronoi Polygons and symbolize graduated on ridership capture areas to show high/low areas. 

# TO DO:
# iterate through bus stop list and find nearest node
# Creates 1/2 mile isochrone for each bus stop nearest node.
